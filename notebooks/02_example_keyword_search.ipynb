# %% [markdown]
# # Example 2: Keyword search in GePaDeU

# %%
import gepadeu
import utils
import glob
import spacy
import pandas as pd
from spacy import displacy

# %% [markdown]
# ### Read data and do some preprocessing.
#
# #### Specify input directory and read input file names.

# %%
indir = '../GePaDeU/speeches_v1'
jfiles = glob.glob(indir + '/*.json')
speeches = []

# %% [markdown]
# #### Read input files and convert them to Gepadeu objects

# %%
for jfile in jfiles: 
    with open(jfile, 'r') as inf: 
        speeches.append(gepadeu.Gepadeu.from_json(inf.read(), jfile))

# %% [markdown]
# #### Extract content for each speech

# %%
content_dict = utils.extract_content(speeches)

# %% [markdown]
# #### Extract metadata for each speech

# %%
meta_dict = utils.extract_metadata(speeches)

# %% [markdown]
# #### Search for specific keywords and return their token ids as a list

# %%
# Replace 'Freiheit' with your own keyword
keyword = 'Freiheit'
keyword_ids, num_instances = utils.search_for(speeches, keyword)

# %%
# Print the number of keyword instances found in the data
print("Found ", num_instances, "instances of <", keyword, ">")
# Out:
# Found  63 instances of < Freiheit >

# %% [markdown]
# #### Get all speech act annotations (if any) for the keywords

# %%
annotations = utils.get_annotations_by_id(keyword_ids, speeches, ['speechact'])

# %% [markdown]
# ##### Display sentences that include the keyword and show speech act annotations. Also print speaker name, party affiliation and date the speech was given.

# %%
annot_dict = gepadeu.Gepadeu.display_keyword_with_annots(annotations, meta_dict, ['speechact'], 'display')
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Danken
#
# <span style="background: #999933; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #999933; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #999933; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Expressive
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     möchte
#
# <span style="background: #999933; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# ...

# %% [markdown]
# #### Now add moral foundation annotations and display the results.

# %%
keyword_ids, num_instances = utils.search_for(speeches, keyword)
layers = ['speechact', 'moral', 'mf']
# Get all annotations (if any) for the annotation layers and the specified word
annotations = utils.get_annotations_by_id(keyword_ids, speeches, layers)
# Show annotations for speech acts and moral frame types. 
annot_dict = gepadeu.Gepadeu.display_keyword_with_annots(annotations, meta_dict, ['speechact', 'moral'], 'display')
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Danken
#
# <span style="background: #999933; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #999933; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #999933; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Expressive
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     möchte
#
# <span style="background: #999933; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# ...

# %% [markdown]
# For each party, print frequency for each annotated label for this keyword.
#
# The last argument specifies the annotation layer to be extracted.

# %%
df = utils.keyword_per_party(keyword, annot_dict, meta_dict, 'moral') 
df
# Out:
# KEYWORD: Freiheit 	LAYER: moral
# AfD 	 MoralActOrGoal 	 5
# AfD 	 MoralValue 	 1
# AfD 	 ImmoralActOrGoal 	 4
# CDU_CSU 	 MoralActOrGoal 	 3
# CDU_CSU 	 MoralValue 	 2
# FDP 	 MoralActOrGoal 	 2
# FDP 	 MoralValue 	 1
# GRUENE 	 MoralValue 	 1
# GRUENE 	 MoralActOrGoal 	 1
# GRUENE 	 ImmoralActOrGoal 	 1
# LINKE 	 ImmoralActOrGoal 	 1
# SPD 	 MoralActOrGoal 	 2
# SPD 	 MoralValue 	 2
# fraktionslos 	 MoralActOrGoal 	 1

# %%
# same for SPEECH ACT layer
df = utils.keyword_per_party(keyword, annot_dict, meta_dict, 'speechact')
# Out:
# KEYWORD: Freiheit 	LAYER: speechact
# AfD 	 Demand 	 3
# AfD 	 Rejection 	 1
# AfD 	 Accusation 	 3
# AfD 	 Evaluation 	 2
# AfD 	 Self-representation 	 1
# AfD 	 Promise 	 1
# AfD 	 Request 	 1
# CDU_CSU 	 Evaluation 	 1
# CDU_CSU 	 Request 	 2
# CDU_CSU 	 Self-representation 	 2
# FDP 	 Report 	 1
# FDP 	 Promise 	 1
# FDP 	 Self-representation 	 1
# FDP 	 Evaluation 	 1
# GRUENE 	 Question-All 	 1
# GRUENE 	 Evaluation 	 2
# LINKE 	 Accusation 	 1
# SPD 	 Self-representation 	 1
# SPD 	 Evaluation 	 4
# SPD 	 Request 	 1
# fraktionslos 	 Self-representation 	 1

# %%
# now show the moral foundation annotations for each speech act
annot_dict = gepadeu.Gepadeu.display_keyword_with_annots(annotations, meta_dict, ['speechact', 'mf'], 'display')
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Danken
#
# <span style="background: #999933; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #999933; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #999933; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Expressive
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     möchte
#
# <span style="background: #999933; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# ...
